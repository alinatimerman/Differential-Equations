# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+4*y
deq2=diff(y,t)==x+y
syst=[deq1,deq2]

# %%
desolve_system(syst,[x,y])
# Out:
# [x(t) == 1/2*e^(3*t)*x(0) + 1/2*e^(-t)*x(0),
#  y(t) == 1/4*e^(3*t)*x(0) - 1/4*e^(-t)*x(0)]

# %%
C1,C2=var('C1,C2')
desolve_system(syst,[x,y],[0,C1,C2])
# Out:
# [x(t) == 1/2*(C1 + 2*C2)*e^(3*t) + 1/2*(C1 - 2*C2)*e^(-t),
#  y(t) == 1/4*(C1 + 2*C2)*e^(3*t) - 1/4*(C1 - 2*C2)*e^(-t)]

# %%
sol=desolve_system(syst,[x,y],[0,C1,C2])
sol_x(t,C1,C2)=sol[0].rhs()
sol_x
# Out:
# (t, C1, C2) |--> 1/2*(C1 + 2*C2)*e^(3*t) + 1/2*(C1 - 2*C2)*e^(-t)

# %%
sol_y(t,C1,C2)=sol[1].rhs()
sol_y
# Out:
# (t, C1, C2) |--> 1/4*(C1 + 2*C2)*e^(3*t) - 1/4*(C1 - 2*C2)*e^(-t)

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==2*x-y
deq2=diff(y,t)==x+2*y
syst=[deq1,deq2]

# %%
desolve_system(syst,[x,y])
# Out:
# [x(t) == -(C2*sin(t) - cos(t)*x(0))*e^(2*t),
#  y(t) == (C2*cos(t) + sin(t)*x(0))*e^(2*t)]

# %%
C1,C2=var('C1,C2')
desolve_system(syst,[x,y],[0,C1,C2])
# Out:
# [x(t) == (C1*cos(t) - C2*sin(t))*e^(2*t),
#  y(t) == (C2*cos(t) + C1*sin(t))*e^(2*t)]

# %%
sol=desolve_system(syst,[x,y],[0,C1,C2])
sol_x(t,C1,C2)=sol[0].rhs()
sol_x
# Out:
# (t, C1, C2) |--> (C1*cos(t) - C2*sin(t))*e^(2*t)

# %%
sol_y(t,C1,C2)=sol[1].rhs()
sol_y
# Out:
# (t, C1, C2) |--> (C2*cos(t) + C1*sin(t))*e^(2*t)

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
z=function('z')(t)
deq1=diff(x,t)==x-y+z
deq2=diff(y,t)==x+y-z
deq3=diff(z,t)==-1*y+2*z
syst=[deq1,deq2,deq3]

# %%
desolve_system(syst,[x,y,z])
# Out:
# [x(t) == -C3*t*e^t + t*e^t*x(0) - (C2 - 2*C3 + x(0))*e^(2*t) + (C2 - 2*C3 + 2*x(0))*e^t,
#  y(t) == -C3*t*e^t + t*e^t*x(0) + C2*e^t,
#  z(t) == -C3*t*e^t + t*e^t*x(0) - (C2 - 2*C3 + x(0))*e^(2*t) + (C2 - C3 + x(0))*e^t]

# %%
C1,C2,C3=var('C1,C2,C3')
desolve_system(syst,[x,y,z],[0,C1,C2,C3])
# Out:
# [x(t) == C1*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (2*C1 + C2 - 2*C3)*e^t,
#  y(t) == C1*t*e^t - C3*t*e^t + C2*e^t,
#  z(t) == C1*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (C1 + C2 - C3)*e^t]

# %%
sol=desolve_system(syst,[x,y,z],[0,C1,C2,C3])
sol_x(t,C1,C2,C3)=sol[0].rhs()
sol_x
# Out:
# (t, C1, C2, C3) |--> C1*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (2*C1 + C2 - 2*C3)*e^t

# %%
sol_y(t,C1,C2,C3)=sol[1].rhs()
sol_y
# Out:
# (t, C1, C2, C3) |--> C1*t*e^t - C3*t*e^t + C2*e^t

# %%
sol_z(t,C1,C2,C3)=sol[2].rhs()
sol_z
# Out:
# (t, C1, C2, C3) |--> C1*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (C1 + C2 - C3)*e^t

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==5*x+3*y+1
deq2=diff(y,t)==-6*x-4*y+e**-t
syst=[deq1,deq2]

# %%
desolve_system(syst,[x,y])
# Out:
# [x(t) == 1/3*(3*C2 + 6*x(0) + 4)*e^(2*t) - 1/3*(3*C2 + 3*x(0) - 2)*e^(-t) - t*e^(-t) - 2,
#  y(t) == -1/3*(3*C2 + 6*x(0) + 4)*e^(2*t) + 1/3*(6*C2 + 6*x(0) - 5)*e^(-t) + 2*t*e^(-t) + 3]

# %%
C1,C2=var('C1,C2')
desolve_system(syst,[x,y],[0,C1,C2])
# Out:
# [x(t) == 1/3*(6*C1 + 3*C2 + 4)*e^(2*t) - 1/3*(3*C1 + 3*C2 - 2)*e^(-t) - t*e^(-t) - 2,
#  y(t) == -1/3*(6*C1 + 3*C2 + 4)*e^(2*t) + 1/3*(6*C1 + 6*C2 - 5)*e^(-t) + 2*t*e^(-t) + 3]

# %%
sol=desolve_system(syst,[x,y],[0,C1,C2])
sol_x(t,C1,C2)=sol[0].rhs()
sol_x
# Out:
# (t, C1, C2) |--> 1/3*(6*C1 + 3*C2 + 4)*e^(2*t) - 1/3*(3*C1 + 3*C2 - 2)*e^(-t) - t*e^(-t) - 2

# %%
sol_y(t,C1,C2)=sol[1].rhs()
sol_y
# Out:
# (t, C1, C2) |--> -1/3*(6*C1 + 3*C2 + 4)*e^(2*t) + 1/3*(6*C1 + 6*C2 - 5)*e^(-t) + 2*t*e^(-t) + 3

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+3*y+cos(t)
deq2=diff(y,t)==x-y+2*t
syst=[deq1,deq2]

# %%
desolve_system(syst,[x,y])
# Out:
# [x(t) == 3/40*(10*C2 + 10*x(0) + 9)*e^(2*t) - 1/40*(30*C2 - 10*x(0) + 19)*e^(-2*t) - 3/2*t - 1/5*cos(t) + 1/5*sin(t),
#  y(t) == 1/40*(10*C2 + 10*x(0) + 9)*e^(2*t) + 1/40*(30*C2 - 10*x(0) + 19)*e^(-2*t) + 1/2*t - 1/5*cos(t) - 1/2]

# %%
C1,C2=var('C1,C2')
desolve_system(syst,[x,y],[0,C1,C2])
# Out:
# [x(t) == 3/40*(10*C1 + 10*C2 + 9)*e^(2*t) + 1/40*(10*C1 - 30*C2 - 19)*e^(-2*t) - 3/2*t - 1/5*cos(t) + 1/5*sin(t),
#  y(t) == 1/40*(10*C1 + 10*C2 + 9)*e^(2*t) - 1/40*(10*C1 - 30*C2 - 19)*e^(-2*t) + 1/2*t - 1/5*cos(t) - 1/2]

# %%
sol=desolve_system(syst,[x,y],[0,C1,C2])
sol_x(t,C1,C2)=sol[0].rhs()
sol_x
# Out:
# (t, C1, C2) |--> 3/40*(10*C1 + 10*C2 + 9)*e^(2*t) + 1/40*(10*C1 - 30*C2 - 19)*e^(-2*t) - 3/2*t - 1/5*cos(t) + 1/5*sin(t)

# %%
sol_y(t,C1,C2)=sol[1].rhs()
sol_y
# Out:
# (t, C1, C2) |--> 1/40*(10*C1 + 10*C2 + 9)*e^(2*t) - 1/40*(10*C1 - 30*C2 - 19)*e^(-2*t) + 1/2*t - 1/5*cos(t) - 1/2

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
z=function('z')(t)
deq1=diff(x,t)==x-2*y-2*z+e**(-t)
deq2=diff(y,t)==-2*x+y+2*z
deq3=diff(z,t)==2*x-y-3*z+e**(-t)
syst=[deq1,deq2,deq3]

# %%
desolve_system(syst,[x,y,z])
# Out:
# [x(t) == -1/3*sqrt(3)*(C2 + 2*C3 - 2*x(0))*sinh(sqrt(3)*t) - C2*cosh(sqrt(3)*t) + (C2 + x(0))*e^(-t) + t*e^(-t),
#  y(t) == 1/3*sqrt(3)*(C2 + 2*C3 - 2*x(0))*sinh(sqrt(3)*t) + C2*cosh(sqrt(3)*t),
#  z(t) == -sqrt(3)*(C3 - x(0))*sinh(sqrt(3)*t) - (C2 - C3 + x(0))*cosh(sqrt(3)*t) + (C2 + x(0))*e^(-t) + t*e^(-t)]

# %%
C1,C2,C3=var('C1,C2,C3')
desolve_system(syst,[x,y,z],[0,C1,C2,C3])
# Out:
# [x(t) == 1/3*sqrt(3)*(2*C1 - C2 - 2*C3)*sinh(sqrt(3)*t) - C2*cosh(sqrt(3)*t) + (C1 + C2)*e^(-t) + t*e^(-t),
#  y(t) == -1/3*sqrt(3)*(2*C1 - C2 - 2*C3)*sinh(sqrt(3)*t) + C2*cosh(sqrt(3)*t),
#  z(t) == sqrt(3)*(C1 - C3)*sinh(sqrt(3)*t) - (C1 + C2 - C3)*cosh(sqrt(3)*t) + (C1 + C2)*e^(-t) + t*e^(-t)]

# %%
sol=desolve_system(syst,[x,y,z],[0,C1,C2,C3])
sol_x(t,C1,C2,C3)=sol[0].rhs()
sol_x
# Out:
# (t, C1, C2, C3) |--> 1/3*sqrt(3)*(2*C1 - C2 - 2*C3)*sinh(sqrt(3)*t) - C2*cosh(sqrt(3)*t) + (C1 + C2)*e^(-t) + t*e^(-t)

# %%
sol_y(t,C1,C2,C3)=sol[1].rhs()
sol_y
# Out:
# (t, C1, C2, C3) |--> -1/3*sqrt(3)*(2*C1 - C2 - 2*C3)*sinh(sqrt(3)*t) + C2*cosh(sqrt(3)*t)

# %%
sol_z(t,C1,C2,C3)=sol[2].rhs()
sol_z
# Out:
# (t, C1, C2, C3) |--> sqrt(3)*(C1 - C3)*sinh(sqrt(3)*t) - (C1 + C2 - C3)*cosh(sqrt(3)*t) + (C1 + C2)*e^(-t) + t*e^(-t)

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+4*y
deq2=diff(y,t)==x+y
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,1,2]

# %%
sol=desolve_system(syst,vars,in_cond)
sol
# Out:
# [x(t) == 5/2*e^(3*t) - 3/2*e^(-t), y(t) == 5/4*e^(3*t) + 3/4*e^(-t)]

# %%
sol_x(t)=sol[0].rhs()
sol_x
# Out:
# t |--> 5/2*e^(3*t) - 3/2*e^(-t)

# %%
sol_y(t)=sol[1].rhs()
sol_y
# Out:
# t |--> 5/4*e^(3*t) + 3/4*e^(-t)

# %%
plot(sol_x(t),t,-5,5,color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_y(t),t,-5,5,color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g1=plot(sol_x(t),t,-5,5,color='red')
g2=plot(sol_y(t),t,-5,5,color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x-y+t-1
deq2=diff(y,t)==-2*x+4*y+cos(t)
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,0,1]

# %%
sol=desolve_system(syst,vars,in_cond)
sol
# Out:
# [x(t) == -1/13*(10*sqrt(17)*sinh(1/2*sqrt(17)*t) - 33*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - 2*t - 1/26*cos(t) + 5/26*sin(t) - 5/2,
#  y(t) == -1/26*(3*sqrt(17)*sinh(1/2*sqrt(17)*t) - 71*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - t - 3/13*cos(t) + 2/13*sin(t) - 3/2]

# %%
sol_x(t)=sol[0].rhs()
sol_x
# Out:
# t |--> -1/13*(10*sqrt(17)*sinh(1/2*sqrt(17)*t) - 33*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - 2*t - 1/26*cos(t) + 5/26*sin(t) - 5/2

# %%
sol_y(t)=sol[1].rhs()
sol_y
# Out:
# t |--> -1/26*(3*sqrt(17)*sinh(1/2*sqrt(17)*t) - 71*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - t - 3/13*cos(t) + 2/13*sin(t) - 3/2

# %%
plot(sol_x(t),t,-5,5,color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_y(t),t,-5,5,color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g1=plot(sol_x(t),t,-5,5,color='red')
g2=plot(sol_y(t),t,-5,5,color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+2*t+e**(-t)
deq2=diff(y,t)==-2*x+y+1
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,0,1]

# %%
sol=desolve_system(syst,vars,in_cond)
sol
# Out:
# [x(t) == -2*t - 1/2*e^(-t) + 5/2*e^t - 2,
#  y(t) == -5*t*e^t - 4*t - 1/2*e^(-t) + 21/2*e^t - 9]

# %%
sol_x(t)=sol[0].rhs()
sol_x
# Out:
# t |--> -2*t - 1/2*e^(-t) + 5/2*e^t - 2

# %%
sol_y(t)=sol[1].rhs()
sol_y
# Out:
# t |--> -5*t*e^t - 4*t - 1/2*e^(-t) + 21/2*e^t - 9

# %%
plot(sol_x(t),t,-5,5,color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_y(t),t,-5,5,color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g1=plot(sol_x(t),t,-5,5,color='red')
g2=plot(sol_y(t),t,-5,5,color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
z=function('z')(t)
deq1=diff(x,t)==-x+3*t+3*z+27*t**2
deq2=diff(y,t)==2*x-2*y-5*z+3*t
deq3=diff(z,t)==-2*x+3*y+6*z+3
syst=[deq1,deq2,deq3]
vars=[x,y,z]
in_cond=[0,50,-30,26]

# %%
sol=desolve_system(syst,vars,in_cond)
sol
# Out:
# [x(t) == -27*t^2 - (4*sqrt(2)*sin(sqrt(2)*t) - 57*cos(sqrt(2)*t))*e^t - 30*t + 9*e^t - 16,
#  y(t) == 18*t^2 + 1/3*(65*sqrt(2)*sin(sqrt(2)*t) - 106*cos(sqrt(2)*t))*e^t + 26*t - 4*e^t + 28/3,
#  z(t) == -18*t^2 - 1/3*(65*sqrt(2)*sin(sqrt(2)*t) - 106*cos(sqrt(2)*t))*e^t - 29*t + 6*e^t - 46/3]

# %%
sol_x(t)=sol[0].rhs()
sol_x
# Out:
# t |--> -27*t^2 - (4*sqrt(2)*sin(sqrt(2)*t) - 57*cos(sqrt(2)*t))*e^t - 30*t + 9*e^t - 16

# %%
sol_y(t)=sol[1].rhs()
sol_y
# Out:
# t |--> 18*t^2 + 1/3*(65*sqrt(2)*sin(sqrt(2)*t) - 106*cos(sqrt(2)*t))*e^t + 26*t - 4*e^t + 28/3

# %%
sol_z(t)=sol[2].rhs()
sol_z
# Out:
# t |--> -18*t^2 - 1/3*(65*sqrt(2)*sin(sqrt(2)*t) - 106*cos(sqrt(2)*t))*e^t - 29*t + 6*e^t - 46/3

# %%
plot(sol_x(t),t,-5,5,color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_y(t),t,-5,5,color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_z(t),t,-5,5,color='green')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g1=plot(sol_x(t),t,-2,2,color='red')
g2=plot(sol_y(t),t,-2,2,color='blue')
g3=plot(sol_z(t),t,-2,2,color='green')
show(g1+g2+g3)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+y
deq2=diff(y,t)==-2*x+4*y
syst=[deq1,deq2]
vars=[x,y]
in_cond1=[0,3,0]
in_cond2=[0,0,3]
in_cond3=[0,-3,0]
in_cond4=[0,0,-3]
sol1=desolve_system(syst,vars,in_cond1)
sol2=desolve_system(syst,vars,in_cond2)
sol3=desolve_system(syst,vars,in_cond3)
sol4=desolve_system(syst,vars,in_cond4)

# %%
sol1
# Out:
# [x(t) == -3*e^(3*t) + 6*e^(2*t), y(t) == -6*e^(3*t) + 6*e^(2*t)]

# %%
sol2
# Out:
# [x(t) == 3*e^(3*t) - 3*e^(2*t), y(t) == 6*e^(3*t) - 3*e^(2*t)]

# %%
sol1_x(t)=sol1[0].rhs()
sol1_y(t)=sol1[1].rhs()

# %%
limit(sol1_x(t),t=infinity)
# Out:
# -Infinity

# %%
limit(sol1_y(t),t=infinity)
# Out:
# -Infinity

# %%
sol2_x(t)=sol2[0].rhs()
sol2_y(t)=sol2[1].rhs()

# %%
limit(sol2_x(t),t=infinity)
# Out:
# +Infinity

# %%
limit(sol2_y(t),t=infinity)
# Out:
# +Infinity

# %%
sol3_x(t)=sol3[0].rhs()
sol3_y(t)=sol3[1].rhs()

# %%
limit(sol3_x(t),t=infinity)
# Out:
# +Infinity

# %%
limit(sol3_y(t),t=infinity)
# Out:
# +Infinity

# %%
sol4_x(t)=sol4[0].rhs()
sol4_y(t)=sol4[1].rhs()

# %%
limit(sol4_x(t),t=infinity)
# Out:
# -Infinity

# %%
limit(sol4_y(t),t=infinity)
# Out:
# -Infinity

# %%
f1(u,v)=u+v
f2(u,v)=-2*u+4*v
g0=plot_vector_field([f1(u,v),f2(u,v)],[u,-5,5],[v,-5,5],color='red',aspect_ratio=1)
g1=parametric_plot((sol1_x(t),sol1_y(t)),(t,-10,10),color='blue')
g2=parametric_plot((sol2_x(t),sol2_y(t)),(t,-10,10),color='green')
g3=parametric_plot((sol3_x(t),sol3_y(t)),(t,-10,10),color='purple')
g4=parametric_plot((sol4_x(t),sol4_y(t)),(t,-10,10),color='black')
g=g0+g1+g2+g3+g4
g.show(xmin=-5,xmax=5,ymin=-5,ymax=5)
# Out:
# Graphics object consisting of 5 graphics primitives
